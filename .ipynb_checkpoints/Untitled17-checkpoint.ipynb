# %% [markdown]
# 1. MAE: It calculates the average absolute difference between actual and predicted values.
# 2. MSE (Mean Squared Error): Instead if absolute errors, it squares each error.
# 3. RMSE (Root Mean Squared Error): It brings the values to the original unit.
# 4. R2 Score ( Cofficient of Determination)
# R2 tells how much of the variation in the target variable is explained by the model.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import(mean_absolute_error,mean_squared_error,r2_score)

# %%
df=pd.read_csv("placement1.csv")

# %%
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
X=df.drop('package',axis=1)

# %%
y=df['package']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.20,random_state=42)

# %%
print(len(X_train))
print(len(X_test))
# Out:
# 160
# 40

# %%
print(len(y_train))
# Out:
# 160

# %%
model=LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(X_test)
y_pred
# Out:
# array([2.78031348, 3.13635249, 3.1995207 , 2.38981908, 3.52684689,
#        3.76803461, 3.16506531, 2.54486832, 3.17655044, 3.4923915 ,
#        1.90744364, 2.34962112, 3.6876387 , 2.75734322, 3.47516381,
#        3.04447145, 2.32665086, 3.20526327, 2.17734418, 3.314372  ,
#        2.45298729, 2.90090734, 3.32011456, 2.87219451, 3.33734226,
#        2.19457187, 1.41932564, 2.7114027 , 3.18229301, 2.32665086,
#        3.74506435, 2.95833298, 3.68189614, 2.97556068, 2.59080884,
#        3.34882738, 2.47595755, 3.07318428, 4.17575671, 2.95833298])

# %%
# mae: 
mae_error=mean_absolute_error(y_test,y_pred)
print(f'mae_error: val is: {mae_error}')#model's predictions are off by approximately 0.232 units on average
# Out:
# mae_error: val is: 0.23150985393278373

# %%
mse_error=mean_squared_error(y_test,y_pred)
print(f'mse_error: val is: {mse_error}')# It gives average of the squared difference between actual and predicted values.
# Out:
# mse_error: val is: 0.08417638361329656

# %%
rsme_error=np.sqrt(mse_error)
print(f'rsme_error val is: {rsme_error}')
# Out:
# rsme_error val is: 0.2901316659954521

# %%
r2=r2_score(y_test,y_pred)
print(f'r2: val is : {r2}')# This means the expression explains 77% accuracy #Higher the value more accuracy (100%)
# Out:
# r2: val is : 0.7730984312051673

# %%
#predict new package
new_cgpa=[[8.0]]
#6.93 2.46

#7.63	3.96

#6.22 2.33

new_cgpa=[[6.93]]

new_cgpa=[[7.63]]

new_cgpa=[[6.22]]
predicted_package=model.predict(new_cgpa)

print("CGPA",8.0)
print("Predicted Package:",predicted_package[0])
# Out:
# CGPA 8.0
# Predicted Package: 2.5448683227517295
# C:\Users\aayus\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
mae_error=mean_absolute_error([2.46],[2.95])
print(f'mae_error val is:{mae_error}')
# Out:
# mae_error val is:0.4900000000000002

# %%
cofficient=pd.DataFrame({'Feature':X.columns,
                         "Cofficient":model.coef_
                        })
print("\n model Cofficients:")
print(cofficient)#Cofficient==slope
# Out:
#  model Cofficients:
#   Feature  Cofficient
# 0    cgpa    0.574256
