# %%
import pandas as pd

# %%
df=pd.read_csv('nyc_weather-905010.csv')
head=df.head(5)
head
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 0  1/1/2016           38        23        52                 30.03
# 1  1/2/2016           36        18        46                 30.02
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 0               10           8.0               0           5    NaN
# 1               10           7.0               0           3    NaN
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 0             281
# 1             275
# 2             277
# 3             345
# 4             333

# %%
maxTemp=df['Temperature'].max()
print('max temp...',maxTemp)
# Out:
# max temp... 50

# %%
maxTemp
# Out:
# np.int64(50)

# %%
df.columns
# Out:
# Index(['EST', 'Temperature', 'DewPoint', 'Humidity', 'Sea Level PressureIn',
#        'VisibilityMiles', 'WindSpeedMPH', 'PrecipitationIn', 'CloudCover',
#        'Events', 'WindDirDegrees'],
#       dtype='str')

# %%
len(df)
# Out:
# 31

# %%
print(df['Temperature'].min())
# Out:
# 20

# %%
lastThree=df.tail(3)
lastThree
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 28  1/29/2016           36        21        50                 29.58
# 29  1/30/2016           34        16        46                 30.01
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 28               10           8.0               0           4    NaN
# 29               10           7.0               0           0    NaN
# 30               10           5.0               0           0    NaN
#
#     WindDirDegrees
# 28             298
# 29             257
# 30             241

# %%
rows=df[2:5]
print(rows)
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
tempEvent=df[['Temperature','Events']]
tempEvent
# Out:
#     Temperature    Events
# 0            38       NaN
# 1            36       NaN
# 2            40       NaN
# 3            25       NaN
# 4            20       NaN
# 5            33       NaN
# 6            39       NaN
# 7            39       NaN
# 8            44      Rain
# 9            50      Rain
# 10           33       NaN
# 11           35       NaN
# 12           26       NaN
# 13           30       NaN
# 14           43       NaN
# 15           47      Rain
# 16           36  Fog-Snow
# 17           25      Snow
# 18           22       NaN
# 19           32       NaN
# 20           31       NaN
# 21           26      Snow
# 22           26  Fog-Snow
# 23           28      Snow
# 24           34       NaN
# 25           43       NaN
# 26           41      Rain
# 27           37       NaN
# 28           36       NaN
# 29           34       NaN
# 30           46       NaN

# %%
t=df[df.Temperature>=40]
t
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2    1/3/2016           40        21        47                 29.86
# 8    1/9/2016           44        38        77                 30.16
# 9   1/10/2016           50        46        71                 29.59
# 14  1/15/2016           43        31        62                 29.82
# 15  1/16/2016           47        37        70                 29.52
# 25  1/26/2016           43        29        56                 30.03
# 26  1/27/2016           41        22        45                 30.03
# 30  1/31/2016           46        28        52                 29.90
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2                10           8.0               0           1    NaN
# 8                 9           8.0               T           8   Rain
# 9                 4           NaN             1.8           7   Rain
# ...

# %%
df[df.Temperature==df.Temperature.max()]
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
th=df[(df.Temperature==50) & (df.Humidity==71)]
th
# Out:
#          EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 9  1/10/2016           50        46        71                 29.59
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 9                4           NaN             1.8           7   Rain
#
#    WindDirDegrees
# 9             109

# %%
dc=df[(df.DewPoint==22) & (df.CloudCover==3)]
dc
# Out:
#           EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 26  1/27/2016           41        22        45                 30.03
#
#     VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 26               10           7.0               T           3   Rain
#
#     WindDirDegrees
# 26             311

# %%
result=df.loc[2]
result
# Out:
# EST                     1/3/2016
# Temperature                   40
# DewPoint                      21
# Humidity                      47
# Sea Level PressureIn       29.86
# VisibilityMiles               10
# WindSpeedMPH                 8.0
# PrecipitationIn                0
# CloudCover                     1
# Events                       NaN
# WindDirDegrees               277
# Name: 2, dtype: object

# %%
df=df[2:5]
df
# Out:
#         EST  Temperature  DewPoint  Humidity  Sea Level PressureIn  \
# 2  1/3/2016           40        21        47                 29.86
# 3  1/4/2016           25         9        44                 30.05
# 4  1/5/2016           20        -3        41                 30.57
#
#    VisibilityMiles  WindSpeedMPH PrecipitationIn  CloudCover Events  \
# 2               10           8.0               0           1    NaN
# 3               10           9.0               0           3    NaN
# 4               10           5.0               0           0    NaN
#
#    WindDirDegrees
# 2             277
# 3             345
# 4             333

# %%
df.reset_index(names='old_index', inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.reset_index(names='old_index', inplace=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\frame.py:7338, in DataFrame.reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    7334                     level_values = algorithms.take(
#    7335                         level_values, lab, allow_fill=True, fill_value=lev._na_value
#    7336                     )
#    7337
# -> 7338                 new_obj.insert(
#    7339                     0,
#    7340                     name,
#    7341                     level_values,
#
# ...
