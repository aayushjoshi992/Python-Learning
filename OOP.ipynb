# %% [markdown]
# ##OOP: Object oriented programming (OOP)is a programming approach where software is orgranized around
# objects. An object cobines data(attributes) and functions(methods) that operate on that data.

# %%
class Student:
    name='ram'
    age=20
    course='python'

    def sdetail(self):
        print(self.name)
        print(self.age)
    def cdetail(self):
        print(self.course)
    de

s=Student() #Object creation
s.sdetail()
print(s.name)
s.cdetail()
# Out:
# ram
# 20
# ram
# python
