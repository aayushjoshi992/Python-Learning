# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("placement.csv")
df
# Out:
#      cgpa  package
# 0    6.89     3.26
# 1    5.12     1.98
# 2    7.82     3.25
# 3    7.42     3.67
# 4    6.94     3.57
# ..    ...      ...
# 195  6.93     2.46
# 196  5.89     2.57
# 197  7.21     3.24
# 198  7.63     3.96
# 199  6.22     2.33
#
# [200 rows x 2 columns]

# %%
plt.scatter(df['cgpa'],df['package'])
# plt.plot(df['cgpa'],df['package'])
plt.xlabel(df['cgpa'])
plt.ylabel(df['package'])
plt.title('Package (lpa) with cgpa')
plt.show()

# %%
c=df.columns

# %%
c
# Out:
# Index(['cgpa', 'package'], dtype='str')

# %%
X=df[['cgpa']]

# %%
X.head()
# Out:
#    cgpa
# 0  6.89
# 1  5.12
# 2  7.82
# 3  7.42
# 4  6.94

# %%
y=df['package']

# %%
print(type(X))
# Out:
# <class 'pandas.DataFrame'>

# %%
print(type(y))
# Out:
# <class 'pandas.Series'>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# y= mx + c

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2)

# %%
len(X_train)
# Out:
# 160

# %%
len(X_test)
# Out:
# 40

# %%
len(y_train)
# Out:
# 160

# %%
lr= LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
y_pred
# Out:
# array([2.47418796, 3.34218601, 4.36164681, 3.65676249, 2.37515462,
#        2.99265659, 3.72084288, 2.22369188, 2.8703213 , 3.66258798,
#        2.78876443, 3.08003895, 4.40242524, 2.48583894, 2.34020168,
#        3.97716445, 3.45869582, 4.20435857, 3.49364876, 3.06838797,
#        2.34020168, 1.69357226, 4.14027818, 2.84701934, 1.7285252 ,
#        2.42758404, 2.87614679, 4.33251936, 2.6314762 , 4.51893505,
#        3.70336641, 3.50529974, 2.51496639, 2.67808012, 2.09553109,
#        3.21402522, 3.5286017 , 3.80239974, 3.71501739, 2.42175855])

# %%
plt.scatter(df['cgpa'],df['package'])
y_predicted_val=lr.predict(X_test)
plt.plot(X_test,y_predicted_val, color='red')
plt.xlabel(df['cgpa'])
plt.ylabel(df['package'])
plt.title('Package (lpa) with cgpa')
plt.show()

# %%
#7.82 3.25

# %%
y_pred=lr.predict[[7.82]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 y_pred=lr.predict[[7.82]]
#
# TypeError: 'method' object is not subscriptable
